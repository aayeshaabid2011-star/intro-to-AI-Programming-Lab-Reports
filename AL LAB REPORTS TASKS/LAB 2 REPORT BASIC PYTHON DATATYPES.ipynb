# %% [markdown]
# ## Lab Report Tasks:
# Find Total Impedance

# %%
import cmath

V = complex(240, 0)   

Z = complex(20, 40)   

I = V / Z

print("Current phasor (I):", I)
print("Magnitude of Current |I| =", abs(I))
print("Phase angle of Current (radians) =", cmath.phase(I))
print("Phase angle of Current (degrees) =", cmath.phase(I) * 180 / 3.14159)
# Out:
# Current phasor (I): (2.4-4.8j)
# Magnitude of Current |I| = 5.366563145999495
# Phase angle of Current (radians) = -1.1071487177940904
# Phase angle of Current (degrees) = -63.43500240417632

# %% [markdown]
# ---
